# %%
from io import StringIO
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import datetime
import time

# %%
Stock_list = pd.read_csv('name.csv')['name']
date = pd.read_csv('date.csv')['date']
Stock = pd.read_csv('model2.csv')

# %% [markdown]
# import sys
# import math
#
# for i in Stock.columns:
#     for j in range(len(Stock)) :
#         K = Stock[i][j]
#         if K > sys.maxsize:
#             print ('inf' , i , j)
#         try :
#             if math.isnan(K):
#                 print ('nan' , i , j)
#         except Exception as e:
#             print(e, i)

# %% [markdown]
# def rise_estimate(df, day , upper , lower):
#     i=0
#     label = "p" + str(day) + "_" + str(upper)
#     list_ = []
#     while i < len(df):
#         try :
#             U =(max(df['收盤價'][i+1:i+day+1])-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
#
#             if U > upper :
#                 list_.append(1)
#             else :
#                 list_.append(0)
#         except Exception as e:
#             print(e, i )
#             list_.append(0)
#         i+=1
#     df[label] = list_

# %%
def drop_estimate(df, day , upper , lower):
    i=0
    label = "d" + str(day) + "_" + str(upper)
    list_ = []
    while i < len(df):
        try :
            UP = df['收盤價'][i+1:i+day+1].tolist()
            LP = df['最高價'][i+1:i+day+1].tolist()
            U =(min(UP)-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
            L =(max(LP)-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001) 
            
            if ( U < -upper ) :
                if (L > -lower ):
                    list_.append(1)
                else:
                    list_.append(0)                             
            else :
                list_.append(0)
        except Exception as e:
            print(e, i )
            list_.append(0)
        i+=1
    df[label] = list_

# %%
def rise_estimate(df, day , upper , lower):
    i=0
    label = "p" + str(day) + "_" + str(upper)
    list_ = []
    K = 0
    while i < len(df):
        try :
            UP = df['收盤價'][i+1:i+day+1].tolist()
            LP = df['最低價'][i+1:i+day+1].tolist()
            U =(max(UP)-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
            L =(min(LP)-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
            
            if U > upper :
                if (L < lower)  :
                    list_.append(0)
                else:
                    list_.append(1)
            else :
                list_.append(0)
        except Exception as e:
            print(e, i )
            list_.append(0)
        i+=1
    df[label] = list_

# %% [markdown]
# def rise_estimate(df, day , upper , lower):
#     i=0
#     label = "p" + str(day) + "_" + str(upper)
#     list_ = []
#     while i < len(df):
#         try :
#             U =(max(df['收盤價'][i+1:i+day+1])-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
#             L =(min(df['最低價'][i+1:i+day+1])-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
#
#             if U > upper and L > lower :
#                 list_.append(1)
#             else :
#                 list_.append(0)
#         except Exception as e:
#             print(e, i )
#             list_.append(0)
#         i+=1
#     df[label] = list_

# %%
def shift_rise_estimate(df, day , upper ):
    i=0
    label = "pre" + str(day) + "_" + str(upper)
    list_ = [0 for x in range(day)]
    while i < (len(df) -day):
        try :
        
            U =(max(df['最高價'][i+1:i+day+1])-float(df['開盤價'][i]))/float(df['開盤價'][i])

            if U > upper :
                list_.append(1)
            else :
                list_.append(0)
                
        except Exception as e:
            print(e , i)
            list_.append(0)
        i+=1
    df[label] = list_

# %%
def shift_drop_estimate(df, day , upper ):
    i=0
    label = "pre" + str(day) + "__" + str(upper)
    list_ = [0 for x in range(day)]
    while i < (len(df) -day):
        try :
        
            U =(min(df['最低價'][i+1:i+day+1])-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1])

            if -U > upper :
                list_.append(1)
            else :
                list_.append(0)
                
        except Exception as e:
            print(e , i)
            list_.append(0)
        i+=1
    df[label] = list_

# %%
day = 3
upper = 0.05
lower = -0.03
labelp = "p" + str(day) + "_" + str(upper)
labeld = "d" + str(day) + "_" + str(upper)
rise_estimate(Stock, day , upper , lower)
drop_estimate(Stock, day , upper , lower)
# Out:
# max() arg is an empty sequence 312972
# min() arg is an empty sequence 312972

# %%
days = [3,2,1]
uppers = [0.05, 0.03 ,0.02 ]
for i in range(len(days)):
    shift_rise_estimate(Stock, days[i] , uppers[i])
    shift_drop_estimate(Stock, days[i] , uppers[i])

# %%
Stock.columns.values
# Out:
# array(['證券代號', '成交股數', '成交筆數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差',
#        '本益比', '融資買', '融資賣', '融資餘', '融卷買', '融卷賣', '融卷餘', 'ratio', '外資進出',
#        '外資進', '外資出', '投信進出', '投信進', '投信出', '自營進出', '自營進', '自營出', '避險進出',
#        '避險進', '避險出', '三大', 'date', 'MA5', 'MA10', 'MA20', 'MA60', 'buy5',
#        'buy10', '外5', '外10', '投5', '投10', '自5', '三大5', '三大10', 'MA交叉型態2',
#        'K', 'D', 'KD交叉型態', 'KD交叉型態2', '漲跌', 'RSI5', 'RSI10', 'RSI交叉型態',
#        'MA5 slope', 'MA10 slope', 'MA60 slope', 'ratio slope',
#        'margin slope', 'short slope', '三大 slope', '外資5 slope',
#        '外資10 slope', '投信5 slope', '投信10 slope', '自營 slope', 'buy5 slope',
#        'buy10 slope', '金額 slope', 'RSI5鈍化', '外5金', '投5金', '自5金', '融資金',
#        '融卷金', 'D5', 'D5_10', 'D5_60', 'D三大', 'D外資', 'D投信', 'D_upper_day',
#        'UD5', 'UD60', '均線糾結1', '均線糾結2', '三陽開泰', '前高', '波段前高', '突破前高',
#        '均買量', 'R_散戶', 'p3_0.05', 'd3_0.05', 'pre3_0.05', 'pre3__0.05',
#        'pre2_0.03', 'pre2__0.03', 'pre1_0.02', 'pre1__0.02'], dtype=object)

# %%
Klist = ['成交股數', '成交金額', '最高價', '最低價',
       '收盤價', '漲跌價差', '融資賣', '融資餘', '融卷賣', '融卷餘', '外資進', '外資出', 
         '投信進出', '投信進', '投信出', '三大', 'date','buy5', '三大10', 'K', 'D', 'RSI5',
       'RSI10', 'MA5 slope', 'short slope', '三大 slope',
       '外資5 slope', '外資10 slope', '投信5 slope', '投信10 slope', '自營 slope',
       'buy5 slope',  '投5金', '融卷金','均買量']

Stock['成交股數'].shift(+1)

i=0
while i<len(Klist):
    name=str(Klist[i])
    Stock[(name+"比率")]=""
    temp=Stock[name].shift(+1)
    Stock[(name+"比率")]=Stock[name]/(temp+0.000001)
    i+=1
Stock

# %% [markdown]
# columns = Stock.columns
# for l in range (len(Stock.columns)):
#     if len(Stock[columns[l]].value_counts())<= 3:
#         Rise = len(Stock[(Stock[columns[l]] > 0) & (Stock['p3_0.05'] ==1) ])
#         Drop = len(Stock[(Stock[columns[l]] > 0) & (Stock['d3_0.05'] ==1) ])
#         print (columns[l] ," : " , Drop/(Rise+0.001) )

# %% [markdown]
# Stock[(Stock.突破前高 == 1) &(Stock.外資進 > 100000)][['外資進', '突破前高','p3_0.06']].hist()

# %%
Stock[labeld].value_counts()
# Out:
# 0    309000
# 1      3973
# Name: d3_0.05, dtype: int64

# %%
Stock[labelp].value_counts()
# Out:
# 0    286269
# 1     26704
# Name: p3_0.05, dtype: int64

# %%
## 只選top50
list_s = pd.read_csv('150股票代號.csv').代號

test = Stock [Stock.證券代號.isin(list_s[0:49])]
test[labelp].value_counts()
# Out:
# 0    15617
# 1      697
# Name: p3_0.05, dtype: int64

# %% [markdown]
# test = Stock[Stock['成交金額'] > 30000000]
#
# test = test[test['融資餘'] > 10]
#
# test[labelp].value_counts()

# %% [markdown]
# day = [5]
# upper = 0.1
# lower = -0.05
# for i in day:
#     drop_estimate(Stock, i , upper , lower)

# %%
test.columns
# Out:
# Index(['證券代號', '成交股數', '成交筆數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差',
#        '本益比',
#        ...
#        '外資10 slope比率', '投信5 slope比率', '投信10 slope比率', '自營 slope比率',
#        'buy5 slope比率', 'buy10 slope比率', '金額 slope比率', '投5金比率', '融卷金比率',
#        '均買量比率'],
#       dtype='object', length=137)

# %%
for_model = test.drop(['成交股數', '成交筆數', '成交金額', '開盤價', '最高價', '最低價',
       '收盤價', '漲跌價差', '融資買', '融資賣', '融資餘', '融卷買', '融卷賣', '融卷餘', '外資進出', '外資進', '外資出', 
        '投信進出', '投信進', '投信出', '自營進出', '自營進',
       '自營出', '避險進出', '避險進', '避險出', '三大', 'MA5', 'MA10', 'MA20',
       'MA60', 'buy5', 'buy10', '外5', '外10', '投5', '投10', '自5', '三大5',
       '三大10', 'K', 'D', 'RSI5', 'RSI10', 'MA5 slope', 'MA10 slope', 'MA60 slope',
       'ratio slope', 'margin slope', 'short slope', '三大 slope',
       '外資5 slope', '外資10 slope', '投信5 slope', '投信10 slope', '自營 slope',
       'buy5 slope', 'buy10 slope', '金額 slope', 'RSI5鈍化', '外5金', '投5金',
       '自5金', '融資金', '融卷金', 'D5', 'D5_10', 'D5_60', 'D三大', 'D外資', 'D投信',
       'D_upper_day', '前高', '波段前高','均買量','UD5'],axis = 1)

# %%
for_model.columns
# Out:
# Index(['證券代號', '本益比', 'ratio', 'date', 'MA交叉型態2', 'K', 'D', 'KD交叉型態',
#        'KD交叉型態2', '漲跌', 'RSI5', 'RSI10', 'RSI交叉型態', 'MA5 slope', 'MA60 slope',
#        'ratio slope', 'margin slope', '三大 slope', '外資5 slope', '外資10 slope',
#        '投信5 slope', '投信10 slope', '自營 slope', 'buy5 slope', 'buy10 slope',
#        '金額 slope', 'RSI5鈍化', 'D5', 'D5_10', 'D5_60', 'D三大', 'D外資', 'D投信',
#        'D_upper_day', 'UD5', 'UD60', '均線糾結1', '均線糾結2', '三陽開泰', '突破前高', 'R_散戶',
#        'p3_0.05', 'd3_0.05', 'pre3_0.05', 'pre3__0.05', 'pre2_0.03',
#        'pre2__0.03', 'pre1_0.02', 'pre1__0.02', '成交股數比率', '成交金額比率', '最高價比率',
#        '最低價比率', '收盤價比率', '漲跌價差比率', '融資賣比率', '融資餘比率', '融卷賣比率', '融卷餘比率',
#        '外資進出比率', '外資進比率', '外資出比率', '投信進出比率', '投信進比率', '投信出比率', '三大比率',
#        'date比率', 'buy5比率', '三大10比率', 'K比率', 'D比率', 'RSI5比率', 'RSI10比率',
#        'MA5 slope比率', 'short slope比率', '三大 slope比率', '外資5 slope比率',
#        '外資10 slope比率', '投信5 slope比率', '投信10 slope比率', '自營 slope比率',
#        'buy5 slope比率', 'buy10 slope比率', '金額 slope比率', '投5金比率', '融卷金比率',
#        '均買量比率'],
#       dtype='object')

# %%
model = for_model[for_model['date'] >  date [len(date)-(80)]]
#normal = normal[normal[labelp] == 0]

#detect = for_model[for_model[labelp] == 1]
#detect = detect[for_model['date'] >  date [len(date)-(70)]]
#model = detect.append(normal)

# %%
model[labeld].value_counts()
# Out:
# 0    12660
# 1       56
# Name: d3_0.05, dtype: int64

# %%
model[labelp].value_counts()
# Out:
# 0    12096
# 1      620
# Name: p3_0.05, dtype: int64

# %%
cost =  model[labelp].value_counts()[0] /  model[labelp].value_counts()[1]

# %%
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import precision_score
from imblearn.under_sampling import RandomUnderSampler
from xgboost import XGBClassifier

K =17
interval = 10
t = model[model['date'] <= date [K]]

trainp = t [t['date'] < date [K+interval] ]
testp = t [t['date'] >= date [K+interval] ]
#ros = RandomOverSampler(random_state42)

X_train = trainp.drop(['date','證券代號', labelp,labeld ],axis = 1)
y_train = trainp[labelp]

X_test = testp.drop(['date', '證券代號',labelp,labeld],axis = 1)
y_test = testp[labelp]
y_test_ = testp[labeld] 

#X_train, y_train = SMOTE(random_state=42).fit_resample(X_train, y_train)
#ros = RandomOverSampler(random_state = 40)

#X_train, y_train = ros.fit_resample(X_train, y_train)

# %%
X_train.columns
# Out:
# Index(['本益比', 'ratio', 'MA交叉型態2', 'K', 'D', 'KD交叉型態', 'KD交叉型態2', '漲跌', 'RSI5',
#        'RSI10', 'RSI交叉型態', 'MA5 slope', 'MA60 slope', 'ratio slope',
#        'margin slope', '三大 slope', '外資5 slope', '外資10 slope', '投信5 slope',
#        '投信10 slope', '自營 slope', 'buy5 slope', 'buy10 slope', '金額 slope',
#        'RSI5鈍化', 'D5', 'D5_10', 'D5_60', 'D三大', 'D外資', 'D投信', 'D_upper_day',
#        'UD5', 'UD60', '均線糾結1', '均線糾結2', '三陽開泰', '突破前高', 'R_散戶', 'pre3_0.05',
#        'pre3__0.05', 'pre2_0.03', 'pre2__0.03', 'pre1_0.02', 'pre1__0.02',
#        '成交股數比率', '成交金額比率', '最高價比率', '最低價比率', '收盤價比率', '漲跌價差比率', '融資賣比率',
#        '融資餘比率', '融卷賣比率', '融卷餘比率', '外資進出比率', '外資進比率', '外資出比率', '投信進出比率',
#        '投信進比率', '投信出比率', '三大比率', 'date比率', 'buy5比率', '三大10比率', 'K比率', 'D比率',
#        'RSI5比率', 'RSI10比率', 'MA5 slope比率', 'short slope比率', '三大 slope比率',
#        '外資5 slope比率', '外資10 slope比率', '投信5 slope比率', '投信10 slope比率',
#        '自營 slope比率', 'buy5 slope比率', 'buy10 slope比率', '金額 slope比率', '投5金比率',
#        '融卷金比率', '均買量比率'],
#       dtype='object')

# %% [markdown]
# from sklearn.ensemble import RandomForestClassifier
# rfc = RandomForestClassifier(bootstrap=True, class_weight={1:0.8,0:0.2}, criterion='gini',
#                        max_depth=25, max_features=30,
#                        min_impurity_decrease=0.005, min_impurity_split=None,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=41, verbose=0,
#                        warm_start=False)

# %% [markdown]
# #rfc = RandomForestClassifier(n_estimators = 200 , max_depth = 20 ,random_state=1,criterion = 'gini')
# rfc = RandomForestClassifier(bootstrap=True, class_weight={1:cost,0:1}, criterion='gini',
#                        max_depth=25, max_features=30,
#                        min_impurity_decrease=0.0005, min_impurity_split=None,
#                        min_weight_fraction_leaf=0.0, n_estimators=1,
#                        n_jobs=-1, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)
# rfc.fit(X_train,y_train)
#
# y_test_predp = rfc.predict(X_test)
# y_train_predp = rfc.predict(X_train)

# %% [markdown]
# from xgboost import XGBClassifier
# xgbc = XGBClassifier(eta = 0.01,max_depth=10,random_state=1,gamma=0.01,min_child_weight = 1,scale_pos_weight = cost,
#                      subsample=0.7,colsample_bytree=0.8,n_estimators=50,objective= 'binary:logistic', seed=27)
# xgbc.fit(X_train,y_train)
# y_test_predp = xgbc.predict(X_test)
# y_train_predp = xgbc.predict(X_train)

# %%
xgbc = XGBClassifier(eta = 0.01,max_depth=8,random_state=1,gamma=0.01,min_child_weight = 1,scale_pos_weight = cost,
                     subsample=0.7,colsample_bytree=0.8,n_estimators=50,objective= 'binary:logistic', seed=27)
xgbc.fit(X_train,y_train)
y_test_predp = xgbc.predict(X_test)
y_train_predp = xgbc.predict(X_train)

# %%
confusion_matrix( y_train ,y_train_predp)
# Out:
# array([[10289,   607],
#        [   54,   478]], dtype=int64)

# %%
y_train.value_counts()
# Out:
# 0    10896
# 1      532
# Name: p3_0.05, dtype: int64

# %%
threshold = 0.58
predicted_proba = xgbc.predict_proba(X_test)
predicted = (predicted_proba [:,1] >= threshold).astype('int')
confusion_matrix(y_test, predicted)
# Out:
# array([[447,   1],
#        [ 46,   1]], dtype=int64)

# %%
precision_score( y_test ,predicted)
# Out:
# 0.5

# %%
confusion_matrix( y_test_ ,predicted)
# Out:
# array([[492,   2],
#        [  1,   0]], dtype=int64)

# %%
threshold = 0.4
i = 0
while i < 50 :
    threshold += (i/2000)
    predicted_proba = xgbc.predict_proba(X_test)
    predicted = (predicted_proba [:,1] >= threshold).astype('int')
    precision = precision_score(y_test, predicted)
    i+=1
    print (threshold ,' : ' ,precision)
# Out:
# 0.4  :  0.16842105263157894
# 0.4005  :  0.16489361702127658
# 0.4015  :  0.16756756756756758
# 0.403  :  0.16939890710382513
# 0.405  :  0.1751412429378531
# 0.40750000000000003  :  0.18452380952380953
# 0.41050000000000003  :  0.18404907975460122
# 0.41400000000000003  :  0.1910828025477707
# 0.41800000000000004  :  0.20134228187919462
# 0.42250000000000004  :  0.20437956204379562
# 0.42750000000000005  :  0.2204724409448819
# 0.43300000000000005  :  0.23008849557522124
# 0.43900000000000006  :  0.2358490566037736
# 0.44550000000000006  :  0.25263157894736843
# 0.45250000000000007  :  0.27058823529411763
# 0.4600000000000001  :  0.3026315789473684
# 0.4680000000000001  :  0.30158730158730157
# 0.4765000000000001  :  0.2641509433962264
# 0.4855000000000001  :  0.3111111111111111
# 0.4950000000000001  :  0.3142857142857143
# 0.5050000000000001  :  0.27586206896551724
# 0.5155000000000001  :  0.30434782608695654
# 0.5265000000000001  :  0.29411764705882354
# 0.538  :  0.2857142857142857
# 0.55  :  0.25
# 0.5625  :  0.25
# 0.5755  :  0.5
# 0.589  :  0.5
# 0.603  :  1.0
# 0.6174999999999999  :  1.0
# 0.6325  :  0.0
# 0.6479999999999999  :  0.0
# 0.6639999999999999  :  0.0
# 0.6804999999999999  :  0.0
# 0.6974999999999999  :  0.0
# 0.7149999999999999  :  0.0
# 0.7329999999999999  :  0.0
# 0.7514999999999998  :  0.0
# 0.7704999999999999  :  0.0
# 0.7899999999999998  :  0.0
# 0.8099999999999998  :  0.0
# 0.8304999999999998  :  0.0
# 0.8514999999999998  :  0.0
# 0.8729999999999998  :  0.0
# 0.8949999999999998  :  0.0
# 0.9174999999999998  :  0.0
# 0.9404999999999998  :  0.0
# 0.9639999999999997  :  0.0
# 0.9879999999999998  :  0.0
# 1.0124999999999997  :  0.0

# %%
threshold = 0.6
predicted_proba = xgbc.predict_proba(X_test)
predicted = (predicted_proba [:,1] >= threshold).astype('int')
precision = precision_score(y_test, predicted)

# %%
t = 0
d_list = []
s_list = []
p_list = []

for i in range(len(predicted)):
    if predicted[i] == 1 :
        d_list.append(int(testp['date'][i:i+1].squeeze()))
        s_list.append(int( testp['證券代號'][i:i+1].squeeze()))
        p_list.append(predicted_proba [:,1][i])
        
        #print (i ,testp['date'][i:i+1].squeeze() , " : ", int( testp['證券代號'][i:i+1].squeeze()) ,'  ', predicted_proba [:,1][i])

selected = pd.DataFrame()
selected['date'] = d_list
selected['代號'] = s_list
selected['score'] = p_list

selected.sort_values(by=['score'] , ascending=False, axis =0 , inplace=True)

# %%
selected[0:10]
# Out:
#         date    代號     score
# 63  20210317  5285  0.693410
# 45  20210317  3504  0.693410
# 49  20210317  3605  0.693036
# 60  20210317  4956  0.692432
# 44  20210317  3346  0.692432
# 75  20210317  8110  0.692372
# 29  20210317  2617  0.692200
# 35  20210317  3006  0.692147
# 42  20210317  3094  0.692047
# 6   20210317  1597  0.691116

# %%
feature=pd.DataFrame()
feature['name'] = X_train.columns
feature['score'] = xgbc.feature_importances_

feature.sort_values(by=['score'] , ascending=False, axis =0 , inplace=True)

feature[-40:]
# Out:
#              name     score
# 24         RSI5鈍化  0.008127
# 15       三大 slope  0.008121
# 22    buy10 slope  0.008114
# 51          融資賣比率  0.008069
# 74    投信5 slope比率  0.008056
# 30            D投信  0.007888
# 28            D三大  0.007853
# 65            K比率  0.007704
# 76     自營 slope比率  0.007681
# 70  short slope比率  0.007658
# 80          投5金比率  0.007647
# 52          融資餘比率  0.007644
# 72    外資5 slope比率  0.007574
# 75   投信10 slope比率  0.007541
# 73   外資10 slope比率  0.007500
# 8            RSI5  0.007465
# 77   buy5 slope比率  0.007435
# 71     三大 slope比率  0.007399
# 58         投信進出比率  0.007364
# 3               K  0.007363
# 59          投信進比率  0.007244
# 61           三大比率  0.007235
# 20       自營 slope  0.007225
# 14   margin slope  0.007201
# 82          均買量比率  0.007121
# 48          最低價比率  0.007111
# 37           突破前高  0.007086
# 19     投信10 slope  0.006857
# 78  buy10 slope比率  0.006787
# 13    ratio slope  0.006786
# 67         RSI5比率  0.006760
# 36           三陽開泰  0.006711
# 18      投信5 slope  0.006445
# 55         外資進出比率  0.005731
# 6         KD交叉型態2  0.004407
# 5          KD交叉型態  0.003682
# 34          均線糾結1  0.000000
# 23       金額 slope  0.000000
# 79     金額 slope比率  0.000000
# 32            UD5  0.000000

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch

# %%
import torch.utils.data as data
import io
import imageio
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
from tqdm import tqdm_notebook as tqdm #pip install tqdm
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd
import numpy as np
import os

# %%
import torchvision.datasets as dset
import torchvision.transforms as transforms

# %%
class network(nn.Module):
    def __init__(self):
        super(network,self).__init__()
        self.L1 = nn.Linear(58,30)
        self.L2 = nn.Linear(30,18)
        self.L3 = nn.Linear(18,10)
        self.L4 = nn.Linear(10,7)
        self.L5 = nn.Linear(7,4)
        self.output = nn.Linear(4,2)
    def forward(self , x):
        x = F.relu(self.L1(x))
        x = F.relu(self.L2(x))
        x = F.relu(self.L3(x))
        x = F.relu(self.L4(x))
        x = F.relu(self.L5(x))
        x = self.output(x)
        return x

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)

# %%
X_train, y_train = ros.fit_resample(X_train, y_train)

# %%
from collections import Counter
print(sorted(Counter(y_train).items()))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_train = X_train_std 

sc.fit(X_test)
X_valid_std = sc.transform(X_test)
X_valid = X_valid_std

# %%
X_train.shape,y_train.shape

# %%
tensor_x = torch.from_numpy(X_train)
tensor_y = torch.from_numpy(y_train.to_numpy())
tensor_y = torch.squeeze(tensor_y)
tensor_x_test = torch.from_numpy(X_valid)
tensor_y_test = torch.from_numpy(y_test.to_numpy())
tensor_y_test = torch.squeeze(tensor_y_test)

# %%
#trans = transforms.Compose([transforms.ToTensor()]) 
#train_set = dset.MNIST(root='.', train=True, download=True ,transform=trans)
#test_set = dset.MNIST(root='.', train=False,transform=trans)
train_set = data.TensorDataset(tensor_x,tensor_y)
test_set = data.TensorDataset(tensor_x_test,tensor_y_test)
train_dataset = data.DataLoader(dataset =  train_set,batch_size=100,shuffle=True)
test_dataset = data.DataLoader(dataset = test_set , batch_size=100)

# %%
use_cuda = torch.cuda.is_available()
use_cuda

# %%
use_cuda = torch.cuda.is_available()
net = network()
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=net.parameters())
loss_history = []
if use_cuda:
    net = net.cuda()
for e in tqdm(range(30)):
    epoch_loss_sum = 0
    for x , y in tqdm(train_dataset):
        if use_cuda:
            x = x.cuda()
            y = y.cuda()
        batch_size = x.shape[0]
        x = x.view(batch_size,-1)
        net_out = net(x.float())
        loss = loss_fn(net_out , y)
        epoch_loss_sum += float(loss.item())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    loss_history.append(epoch_loss_sum)

# %%
correct_count = 0
total_testing = len(test_set)
for x,y in test_dataset:
    if use_cuda:
        x = x.cuda()
        y = y.cuda().detach()
    batch_size = x.shape[0]
    x = x.view(batch_size,-1)
    output = net(x.float()).max(1)[1] #output出來是一個向量
    correct_count += torch.sum(output==y).item()
    #print(torch.sum(output==y))
    #print("output = {}".format(output))
    #print("y = {}".format(y))
    #print("======")
#print(correct_count, total_testing)
#correct_count = correct_count
print('accuracy rate',correct_count/total_testing)

# %%
y_pred = net(tensor_x_test.float()).max(1)[1]
y_prediction = y_pred.detach().cpu().numpy() 
y_prediction

# %%
y_test2 = tensor_y_test.numpy()

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix : ")
confusion_matrix(y_test,y_prediction)

# %%
y_test.value_counts()
