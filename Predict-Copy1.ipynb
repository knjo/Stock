# %%
from io import StringIO
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import datetime
import time

# %%
Stock_list = pd.read_csv('name.csv')['name']
date = pd.read_csv('date.csv')['date']
Stock = pd.read_csv('model2.csv')

# %% [markdown]
# import sys
# import math
#
# for i in Stock.columns:
#     for j in range(len(Stock)) :
#         K = Stock[i][j]
#         if K > sys.maxsize:
#             print ('inf' , i , j)
#         try :
#             if math.isnan(K):
#                 print ('nan' , i , j)
#         except Exception as e:
#             print(e, i)

# %% [markdown]
# def rise_estimate(df, day , upper , lower):
#     i=0
#     label = "p" + str(day) + "_" + str(upper)
#     list_ = []
#     while i < len(df):
#         try :
#             U =(max(df['收盤價'][i+1:i+day+1])-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
#
#             if U > upper :
#                 list_.append(1)
#             else :
#                 list_.append(0)
#         except Exception as e:
#             print(e, i )
#             list_.append(0)
#         i+=1
#     df[label] = list_

# %%
def drop_estimate(df, day , upper , lower):
    i=0
    label = "d" + str(day) + "_" + str(upper)
    list_ = []
    while i < len(df):
        try :
            UP = df['收盤價'][i+1:i+day+1].tolist()
            LP = df['最高價'][i+1:i+day+1].tolist()
            U =(min(UP)-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
            L =(max(LP)-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001) 
            
            if ( U < -upper ) :
                if (L > -lower ) and (LP.index(max(LP)) < UP.index(min(UP))):
                    list_.append(0)
                else:
                    list_.append(1)                   
            else :
                list_.append(0)
        except Exception as e:
            print(e, i )
            list_.append(0)
        i+=1
    df[label] = list_

# %%
def rise_estimate(df, day , upper , lower):
    i=0
    label = "p" + str(day) + "_" + str(upper)
    list_ = []
    K = 0
    while i < len(df):
        try :
            UP = df['收盤價'][i+1:i+day+1].tolist()
            LP = df['最低價'][i+1:i+day+1].tolist()
            U =(max(UP)-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
            L =(min(LP)-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
            
            if U > upper :
                if ((L < lower) and ( LP.index(min(LP)) < UP.index(max(UP)))) :
                    list_.append(0)
                else:
                    list_.append(1)
            else :
                list_.append(0)
        except Exception as e:
            print(e, i )
            list_.append(0)
        i+=1
    df[label] = list_

# %% [markdown]
# def rise_estimate(df, day , upper , lower):
#     i=0
#     label = "p" + str(day) + "_" + str(upper)
#     list_ = []
#     while i < len(df):
#         try :
#             U =(max(df['收盤價'][i+1:i+day+1])-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
#             L =(min(df['最低價'][i+1:i+day+1])-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1]+0.0001)
#
#             if U > upper and L > lower :
#                 list_.append(1)
#             else :
#                 list_.append(0)
#         except Exception as e:
#             print(e, i )
#             list_.append(0)
#         i+=1
#     df[label] = list_

# %%
def shift_rise_estimate(df, day , upper ):
    i=0
    label = "pre" + str(day) + "_" + str(upper)
    list_ = [0 for x in range(day)]
    while i < (len(df) -day):
        try :
        
            U =(max(df['最高價'][i+1:i+day+1])-float(df['開盤價'][i]))/float(df['開盤價'][i])

            if U > upper :
                list_.append(1)
            else :
                list_.append(0)
                
        except Exception as e:
            print(e , i)
            list_.append(0)
        i+=1
    df[label] = list_

# %%
def shift_drop_estimate(df, day , upper ):
    i=0
    label = "pre" + str(day) + "__" + str(upper)
    list_ = [0 for x in range(day)]
    while i < (len(df) -day):
        try :
        
            U =(min(df['最低價'][i+1:i+day+1])-float(df['開盤價'][i+1]))/float(df['開盤價'][i+1])

            if -U > upper :
                list_.append(1)
            else :
                list_.append(0)
                
        except Exception as e:
            print(e , i)
            list_.append(0)
        i+=1
    df[label] = list_

# %%
day = 3
upper = 0.05
lower = -0.03
labelp = "p" + str(day) + "_" + str(upper)
labeld = "d" + str(day) + "_" + str(upper)
rise_estimate(Stock, day , upper , lower)
drop_estimate(Stock, day , upper , lower)
# Out:
# max() arg is an empty sequence 312972
# min() arg is an empty sequence 312972

# %%
days = [5,3,1]
uppers = [0.1 , 0.05 ,0.03 ]
for i in range(len(days)):
    shift_rise_estimate(Stock, days[i] , uppers[i])
    shift_drop_estimate(Stock, days[i] , uppers[i])

# %%
Klist = ['最高價','收盤價']

Stock['成交股數'].shift(+1)

i=0
while i<len(Klist):
    name=str(Klist[i])
    Stock[(name+"比率")]=""
    temp=Stock[name].shift(+1)
    Stock[(name+"比率")]=Stock[name]/(temp+0.000001)
    i+=1
Stock
# Out:
#           證券代號       成交股數    成交筆數         成交金額     開盤價     最高價     最低價  \
# 0       1102.0  7523427.0  1622.0  328627574.0   43.65   43.90   43.50
# 1       1102.0  9199111.0  3299.0  399459552.0   43.65   43.65   43.10
# 2       1102.0  7318067.0  4355.0  316035734.0   43.45   43.55   43.05
# 3       1102.0  7782473.0  2578.0  336104142.0   43.65   43.65   43.05
# 4       1102.0  4437357.0  1844.0  192488652.0   43.50   43.55   43.20
# ...        ...        ...     ...          ...     ...     ...     ...
# 312968  9958.0   936944.0   677.0  105584451.0  112.50  113.50  112.00
# 312969  9958.0   943281.0   798.0  106134049.0  113.50  113.50  112.00
# 312970  9958.0  1375114.0   994.0  155739538.0  113.00  114.00  112.50
# 312971  9958.0  1861530.0  1466.0  212116370.0  114.50  115.50  113.00
# 312972  9958.0  1823149.0  1435.0  203911692.0  113.50  113.50  111.00
#
#            收盤價  漲跌價差    本益比  ...  p2_0.03  d2_0.03  pre5_0.1  pre5__0.1  \
# 0        43.65  0.05  10.47  ...        0        0         0          0
# 1        43.15  0.50  10.35  ...        0        0         0          0
# 2        43.30  0.15  10.38  ...        0        0         0          0
# 3        43.25  0.05  10.37  ...        0        0         0          0
# 4        43.45  0.20  10.42  ...        0        0         0          0
# ...        ...   ...    ...  ...      ...      ...       ...        ...
# 312968  112.50  0.50  31.69  ...        0        0         0          0
# 312969  112.00  0.50  31.55  ...        0        0         0          0
# 312970  114.00  2.00  32.11  ...        0        0         0          0
# 312971  113.50  0.50  31.97  ...        0        0         0          0
# 312972  111.50  2.00  31.41  ...        0        0         0          0
#
#         pre3_0.05  pre3__0.05  pre1_0.03  pre1__0.03     最高價比率     收盤價比率
# 0               0           0          0           0       NaN       NaN
# 1               0           0          0           0  0.994305  0.988545
# 2               0           0          0           0  0.997709  1.003476
# 3               0           0          0           0  1.002296  0.998845
# 4               0           0          0           0  0.997709  1.004624
# ...           ...         ...        ...         ...       ...       ...
# 312968          0           0          0           0  1.000000  1.000000
# 312969          0           0          0           0  1.000000  0.995556
# 312970          0           0          0           0  1.004405  1.017857
# 312971          0           0          0           0  1.013158  0.995614
# 312972          0           0          0           0  0.982684  0.982379
#
# [312973 rows x 101 columns]

# %%
Stock.columns.values
# Out:
# array(['證券代號', '成交股數', '成交筆數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差',
#        '本益比', '融資買', '融資賣', '融資餘', '融卷買', '融卷賣', '融卷餘', 'ratio', '外資進出',
#        '外資進', '外資出', '投信進出', '投信進', '投信出', '自營進出', '自營進', '自營出', '避險進出',
#        '避險進', '避險出', '三大', 'date', 'MA5', 'MA10', 'MA20', 'MA60', 'buy5',
#        'buy10', '外5', '外10', '投5', '投10', '自5', '三大5', '三大10', 'MA交叉型態2',
#        'K', 'D', 'KD交叉型態', 'KD交叉型態2', '漲跌', 'RSI5', 'RSI10', 'RSI交叉型態',
#        'MA5 slope', 'MA10 slope', 'MA60 slope', 'ratio slope',
#        'margin slope', 'short slope', '三大 slope', '外資5 slope',
#        '外資10 slope', '投信5 slope', '投信10 slope', '自營 slope', 'buy5 slope',
#        'buy10 slope', '金額 slope', 'RSI5鈍化', '外5金', '投5金', '自5金', '融資金',
#        '融卷金', 'D5', 'D5_10', 'D5_60', 'D三大', 'D外資', 'D投信', 'D_upper_day',
#        'UD5', 'UD60', '均線糾結1', '均線糾結2', '三陽開泰', '前高', '波段前高', '突破前高',
#        '均買量', 'R_散戶', 'p2_0.03', 'd2_0.03', 'pre5_0.1', 'pre5__0.1',
#        'pre3_0.05', 'pre3__0.05', 'pre1_0.03', 'pre1__0.03', '最高價比率',
#        '收盤價比率'], dtype=object)

# %% [markdown]
# columns = Stock.columns
# for l in range (len(Stock.columns)):
#     if len(Stock[columns[l]].value_counts())<= 3:
#         Rise = len(Stock[(Stock[columns[l]] > 0) & (Stock['p3_0.05'] ==1) ])
#         Drop = len(Stock[(Stock[columns[l]] > 0) & (Stock['d3_0.05'] ==1) ])
#         print (columns[l] ," : " , Drop/(Rise+0.001) )

# %% [markdown]
# Stock[(Stock.突破前高 == 1) &(Stock.外資進 > 100000)][['外資進', '突破前高','p3_0.06']].hist()

# %%
Stock[labeld].value_counts()
# Out:
# 0    281964
# 1     31009
# Name: d2_0.03, dtype: int64

# %%
Stock[labelp].value_counts()
# Out:
# 0    283798
# 1     29175
# Name: p2_0.03, dtype: int64

# %% [markdown]
# ## 只選top50
# list_s = pd.read_csv('150股票代號.csv').代號
#
# test = Stock [Stock.證券代號.isin(list_s[0:49])]
# test[labelp].value_counts()

# %% [markdown]
# test = Stock[Stock['成交金額'] > 30000000]
#
#
# test = test[test['MA60 slope'] > 0]
#
#
# test = test[test['融資餘'] > 10]
#
# test[labelp].value_counts()

# %% [markdown]
# day = [5]
# upper = 0.1
# lower = -0.05
# for i in day:
#     drop_estimate(Stock, i , upper , lower)

# %%
test.columns
# Out:
# Index(['證券代號', '成交股數', '成交筆數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差',
#        '本益比',
#        ...
#        'p2_0.03', 'd2_0.03', 'pre5_0.1', 'pre5__0.1', 'pre3_0.05',
#        'pre3__0.05', 'pre1_0.03', 'pre1__0.03', '最高價比率', '收盤價比率'],
#       dtype='object', length=101)

# %%
for_model = test.drop([ '成交股數', '成交筆數', '成交金額', '開盤價', '最高價', '最低價', '收盤價',
        '漲跌價差', '融資買', '融資賣', '融資餘', '融卷買', '融卷賣', '融卷餘', '外資進出', '外資進', '外資出',  
        '三大', '外5', '投5', 'MA5', 'MA10', 'MA20', 'MA60', 'buy5', 'buy10','外10' , '投10', '自5', '三大5', '三大10',
       '投信進出', '投信進', '投信出', '自營進出', '自營進', '自營出', '避險進出', '避險進', '避險出','突破前高'
        ,'D5', 'D5_10', 'D5_60','R_散戶','金額 slope' ,'前高', '波段前高'],axis = 1)

# %%
for_model.columns
# Out:
# Index(['證券代號', '本益比', 'ratio', 'date', 'MA交叉型態2', 'K', 'D', 'KD交叉型態',
#        'KD交叉型態2', '漲跌', 'RSI5', 'RSI10', 'RSI交叉型態', 'MA5 slope', 'MA10 slope',
#        'MA60 slope', 'ratio slope', 'margin slope', 'short slope', '三大 slope',
#        '外資5 slope', '外資10 slope', '投信5 slope', '投信10 slope', '自營 slope',
#        'buy5 slope', 'buy10 slope', 'RSI5鈍化', '外5金', '投5金', '自5金', '融資金',
#        '融卷金', 'D三大', 'D外資', 'D投信', 'D_upper_day', 'UD5', 'UD60', '均線糾結1',
#        '均線糾結2', '三陽開泰', '均買量', 'p2_0.03', 'd2_0.03', 'pre5_0.1', 'pre5__0.1',
#        'pre3_0.05', 'pre3__0.05', 'pre1_0.03', 'pre1__0.03', '最高價比率', '收盤價比率'],
#       dtype='object')

# %%
model = for_model[for_model['date'] >  date [len(date)-(80)]]
#normal = normal[normal[labelp] == 0]

#detect = for_model[for_model[labelp] == 1]
#detect = detect[for_model['date'] >  date [len(date)-(70)]]
#model = detect.append(normal)

# %%
model[labeld].value_counts()
# Out:
# 0    251
# 1     31
# Name: d2_0.03, dtype: int64

# %%
model[labelp].value_counts()
# Out:
# 0    247
# 1     35
# Name: p2_0.03, dtype: int64

# %%
cost =  model[labelp].value_counts()[0] /  model[labelp].value_counts()[1]

# %%
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import precision_score
from imblearn.under_sampling import RandomUnderSampler
from xgboost import XGBClassifier

K = 10
interval = 20
t = model[model['date'] <= date [K]]

trainp = t [t['date'] < date [K+interval] ]
testp = t [t['date'] >= date [K+interval] ]
#ros = RandomOverSampler(random_state42)

X_train = trainp.drop(['date','證券代號', labelp,labeld ],axis = 1)
y_train = trainp[labelp]

X_test = testp.drop(['date', '證券代號',labelp,labeld],axis = 1)
y_test = testp[labelp]
y_test_ = testp[labeld] 

#X_train, y_train = SMOTE(random_state=42).fit_resample(X_train, y_train)
#ros = RandomOverSampler(random_state = 40)

#X_train, y_train = ros.fit_resample(X_train, y_train)

# %% [markdown]
# from sklearn.ensemble import RandomForestClassifier
# rfc = RandomForestClassifier(bootstrap=True, class_weight={1:0.8,0:0.2}, criterion='gini',
#                        max_depth=25, max_features=30,
#                        min_impurity_decrease=0.005, min_impurity_split=None,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=-1, oob_score=False, random_state=41, verbose=0,
#                        warm_start=False)

# %% [markdown]
# #rfc = RandomForestClassifier(n_estimators = 200 , max_depth = 20 ,random_state=1,criterion = 'gini')
# rfc = RandomForestClassifier(bootstrap=True, class_weight={1:cost,0:1}, criterion='gini',
#                        max_depth=25, max_features=30,
#                        min_impurity_decrease=0.0005, min_impurity_split=None,
#                        min_weight_fraction_leaf=0.0, n_estimators=1,
#                        n_jobs=-1, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)
# rfc.fit(X_train,y_train)
#
# y_test_predp = rfc.predict(X_test)
# y_train_predp = rfc.predict(X_train)

# %% [markdown]
# from xgboost import XGBClassifier
# xgbc = XGBClassifier(eta = 0.01,max_depth=10,random_state=1,gamma=0.01,min_child_weight = 1,scale_pos_weight = cost,
#                      subsample=0.7,colsample_bytree=0.8,n_estimators=50,objective= 'binary:logistic', seed=27)
# xgbc.fit(X_train,y_train)
# y_test_predp = xgbc.predict(X_test)
# y_train_predp = xgbc.predict(X_train)

# %%
xgbc = XGBClassifier(eta = 0.01,max_depth=6,random_state=1,gamma=0.01,min_child_weight = 1,scale_pos_weight = cost,
                     subsample=0.7,colsample_bytree=0.8,n_estimators=50,objective= 'binary:logistic', seed=27)
xgbc.fit(X_train,y_train)
y_test_predp = xgbc.predict(X_test)
y_train_predp = xgbc.predict(X_train)

# %%
confusion_matrix( y_train ,y_train_predp)
# Out:
# array([[217,   3],
#        [  0,  31]], dtype=int64)

# %%
y_train.value_counts()
# Out:
# 0    220
# 1     31
# Name: p2_0.03, dtype: int64

# %%
threshold = 0.59
predicted_proba = xgbc.predict_proba(X_test)
predicted = (predicted_proba [:,1] >= threshold).astype('int')
confusion_matrix(y_test, predicted)
# Out:
# array([[18,  0],
#        [ 3,  0]], dtype=int64)

# %%
precision_score( y_test ,predicted)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.0

# %%
confusion_matrix( y_test_ ,predicted)
# Out:
# array([[20,  0],
#        [ 1,  0]], dtype=int64)

# %%
threshold = 0.3
i = 0
while i < 50 :
    threshold += (i/2000)
    predicted_proba = xgbc.predict_proba(X_test)
    predicted = (predicted_proba [:,1] >= threshold).astype('int')
    precision = precision_score(y_test, predicted)
    i+=1
    print (threshold ,' : ' ,precision)
# Out:
# 0.3  :  0.14285714285714285
# 0.3005  :  0.14285714285714285
# 0.3015  :  0.14285714285714285
# 0.303  :  0.14285714285714285
# 0.305  :  0.14285714285714285
# 0.3075  :  0.14285714285714285
# 0.3105  :  0.14285714285714285
# 0.314  :  0.15789473684210525
# 0.318  :  0.15789473684210525
# 0.3225  :  0.16666666666666666
# 0.3275  :  0.2
# 0.333  :  0.23076923076923078
# 0.339  :  0.2727272727272727
# 0.34550000000000003  :  0.2727272727272727
# 0.35250000000000004  :  0.2727272727272727
# 0.36000000000000004  :  0.1111111111111111
# 0.36800000000000005  :  0.1111111111111111
# 0.37650000000000006  :  0.125
# 0.38550000000000006  :  0.16666666666666666
# 0.3950000000000001  :  0.16666666666666666
# 0.4050000000000001  :  0.0
# 0.4155000000000001  :  0.0
# 0.4265000000000001  :  0.0
# 0.4380000000000001  :  0.0
# 0.4500000000000001  :  0.0
# 0.46250000000000013  :  0.0
# 0.47550000000000014  :  0.0
# 0.48900000000000016  :  0.0
# 0.5030000000000001  :  0.0
# 0.5175000000000001  :  0.0
# 0.5325000000000001  :  0.0
# 0.548  :  0.0
# 0.5640000000000001  :  0.0
# 0.5805  :  0.0
# 0.5975  :  0.0
# 0.615  :  0.0
# 0.633  :  0.0
# 0.6515  :  0.0
# 0.6705  :  0.0
# 0.69  :  0.0
# 0.71  :  0.0
# 0.7304999999999999  :  0.0
# 0.7515  :  0.0
# 0.7729999999999999  :  0.0
# 0.7949999999999999  :  0.0
# 0.8174999999999999  :  0.0
# 0.8404999999999999  :  0.0
# 0.8639999999999999  :  0.0
# 0.8879999999999999  :  0.0
# 0.9124999999999999  :  0.0

# %%
threshold = 0.5
predicted_proba = xgbc.predict_proba(X_test)
predicted = (predicted_proba [:,1] >= threshold).astype('int')
precision = precision_score(y_test, predicted)

# %%
t = 0
d_list = []
s_list = []
p_list = []

for i in range(len(predicted)):
    if predicted[i] == 1 :
        d_list.append(int(testp['date'][i:i+1].squeeze()))
        s_list.append(int( testp['證券代號'][i:i+1].squeeze()))
        p_list.append(predicted_proba [:,1][i])
        
        #print (i ,testp['date'][i:i+1].squeeze() , " : ", int( testp['證券代號'][i:i+1].squeeze()) ,'  ', predicted_proba [:,1][i])

# %%
selected = pd.DataFrame()
selected['date'] = d_list
selected['代號'] = s_list
selected['score'] = p_list

# %%
selected.sort_values(by=['score'] , ascending=False, axis =0 , inplace=True)

# %%
selected[1:20]
# Out:
#         date    代號     score
# 10  20210318  2317  0.590220
# 13  20210319  2357  0.587568
# 7   20210315  2317  0.582652
# 9   20210317  2317  0.580914
# 0   20210312  1476  0.576035
# 12  20210317  2354  0.570057
# 8   20210316  2317  0.559068
# 17  20210316  3481  0.547416
# 3   20210316  2303  0.531168
# 1   20210312  2303  0.527773
# 16  20210312  3481  0.525809
# 5   20210318  2303  0.525166
# 15  20210315  2881  0.521319
# 11  20210319  2317  0.514895
# 4   20210317  2303  0.513877
# 14  20210312  2881  0.503998
# 2   20210315  2303  0.503934

# %%
feature=pd.DataFrame()
feature['name'] = X_train.columns
feature['score'] = xgbc.feature_importances_

feature.sort_values(by=['score'] , ascending=False, axis =0 , inplace=True)

feature[-40:]
# Out:
#             name     score
# 40           均買量  0.025575
# 35           UD5  0.024163
# 44    pre1__0.03  0.021831
# 42    pre3__0.05  0.021695
# 46         收盤價比率  0.020263
# 11     MA5 slope  0.018113
# 0            本益比  0.016774
# 12    MA10 slope  0.016702
# 32           D外資  0.016114
# 4              D  0.015374
# 33           D投信  0.014823
# 3              K  0.014757
# 45         最高價比率  0.014552
# 16   short slope  0.014354
# 31           D三大  0.014308
# 23    buy5 slope  0.014156
# 21    投信10 slope  0.014142
# 15  margin slope  0.014108
# 1          ratio  0.014031
# 28           自5金  0.014017
# 18     外資5 slope  0.013953
# 24   buy10 slope  0.013738
# 27           投5金  0.013729
# 7             漲跌  0.013612
# 20     投信5 slope  0.013318
# 17      三大 slope  0.013183
# 26           外5金  0.012976
# 14   ratio slope  0.012917
# 22      自營 slope  0.012876
# 41     pre3_0.05  0.012680
# 19    外資10 slope  0.012090
# 8           RSI5  0.011570
# 9          RSI10  0.011537
# 10       RSI交叉型態  0.011258
# 2        MA交叉型態2  0.011209
# 5         KD交叉型態  0.010543
# 25        RSI5鈍化  0.010061
# 39          三陽開泰  0.009548
# 6        KD交叉型態2  0.009398
# 43     pre1_0.03  0.007049

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch

# %%
import torch.utils.data as data
import io
import imageio
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
from tqdm import tqdm_notebook as tqdm #pip install tqdm
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd
import numpy as np
import os

# %%
import torchvision.datasets as dset
import torchvision.transforms as transforms
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-220-44bfd20cd0ca> in <module>
# ----> 1 import torchvision.datasets as dset
#       2 import torchvision.transforms as transforms
#
# ModuleNotFoundError: No module named 'torchvision'

# %%
class network(nn.Module):
    def __init__(self):
        super(network,self).__init__()
        self.L1 = nn.Linear(58,30)
        self.L2 = nn.Linear(30,18)
        self.L3 = nn.Linear(18,10)
        self.L4 = nn.Linear(10,7)
        self.L5 = nn.Linear(7,4)
        self.output = nn.Linear(4,2)
    def forward(self , x):
        x = F.relu(self.L1(x))
        x = F.relu(self.L2(x))
        x = F.relu(self.L3(x))
        x = F.relu(self.L4(x))
        x = F.relu(self.L5(x))
        x = self.output(x)
        return x

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)

# %%
X_train, y_train = ros.fit_resample(X_train, y_train)

# %%
from collections import Counter
print(sorted(Counter(y_train).items()))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_train = X_train_std 

sc.fit(X_test)
X_valid_std = sc.transform(X_test)
X_valid = X_valid_std

# %%
X_train.shape,y_train.shape

# %%
tensor_x = torch.from_numpy(X_train)
tensor_y = torch.from_numpy(y_train.to_numpy())
tensor_y = torch.squeeze(tensor_y)
tensor_x_test = torch.from_numpy(X_valid)
tensor_y_test = torch.from_numpy(y_test.to_numpy())
tensor_y_test = torch.squeeze(tensor_y_test)

# %%
#trans = transforms.Compose([transforms.ToTensor()]) 
#train_set = dset.MNIST(root='.', train=True, download=True ,transform=trans)
#test_set = dset.MNIST(root='.', train=False,transform=trans)
train_set = data.TensorDataset(tensor_x,tensor_y)
test_set = data.TensorDataset(tensor_x_test,tensor_y_test)
train_dataset = data.DataLoader(dataset =  train_set,batch_size=100,shuffle=True)
test_dataset = data.DataLoader(dataset = test_set , batch_size=100)

# %%
use_cuda = torch.cuda.is_available()
use_cuda

# %%
use_cuda = torch.cuda.is_available()
net = network()
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=net.parameters())
loss_history = []
if use_cuda:
    net = net.cuda()
for e in tqdm(range(30)):
    epoch_loss_sum = 0
    for x , y in tqdm(train_dataset):
        if use_cuda:
            x = x.cuda()
            y = y.cuda()
        batch_size = x.shape[0]
        x = x.view(batch_size,-1)
        net_out = net(x.float())
        loss = loss_fn(net_out , y)
        epoch_loss_sum += float(loss.item())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    loss_history.append(epoch_loss_sum)

# %%
correct_count = 0
total_testing = len(test_set)
for x,y in test_dataset:
    if use_cuda:
        x = x.cuda()
        y = y.cuda().detach()
    batch_size = x.shape[0]
    x = x.view(batch_size,-1)
    output = net(x.float()).max(1)[1] #output出來是一個向量
    correct_count += torch.sum(output==y).item()
    #print(torch.sum(output==y))
    #print("output = {}".format(output))
    #print("y = {}".format(y))
    #print("======")
#print(correct_count, total_testing)
#correct_count = correct_count
print('accuracy rate',correct_count/total_testing)

# %%
y_pred = net(tensor_x_test.float()).max(1)[1]
y_prediction = y_pred.detach().cpu().numpy() 
y_prediction

# %%
y_test2 = tensor_y_test.numpy()

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix : ")
confusion_matrix(y_test,y_prediction)

# %%
y_test.value_counts()
